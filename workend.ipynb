# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersondemota/AulasSenaiPython/blob/main/workend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-381010e3-57ef-4dfc-8d55-9b0918c32564" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-381010e3-57ef-4dfc-8d55-9b0918c32564">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
dataset = list(uploaded.keys())[0]

# %%
data = uploaded[dataset]

# %%
df = pd.read_excel(io.BytesIO(data))

# %%
df.head()
# Out:
#   Data do Pedido                             ID Pedido  Valor Pedido  \
# 0     2023-06-11  00005d78-6f97-4699-a746-19826f415e38        367.63
# 1     2023-07-08  0001dc8e-f58f-45ed-8bf2-5c820c9a30d7        419.80
# 2     2023-05-12  00026f89-7729-43b4-8b37-5185bd77d157        330.73
# 3     2023-11-26  000b9069-e507-406a-8586-d0c005afb71f        157.04
# 4     2023-12-13  000c7595-7278-4b67-93be-f7eb02c81f3c        287.97
#
#      Região  Total Itens Entregues  Volume Não Entregue Hora da Entrega  \
# 0   Sanford                     18                    0        15:00:45
# 1    Apopka                     19                    0        18:11:41
# 2  Clermont                     14                    0        18:26:19
# 3    Apopka                     10                    0        19:46:32
# 4  Clermont                      3                    0        20:12:43
#
#   ID Entregador     Nome Motorista  Idade Motorista  Viagens ID Consumidor  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13002 entries, 0 to 13001
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Data do Pedido         13002 non-null  object
#  1   ID Pedido              13002 non-null  object
#  2   Valor Pedido           13002 non-null  float64
#  3   Região                 13002 non-null  object
#  4   Total Itens Entregues  13002 non-null  int64
#  5   Volume Não Entregue    13002 non-null  int64
#  6   Hora da Entrega        13002 non-null  object
#  7   ID Entregador          13002 non-null  object
#  8   Nome Motorista         13002 non-null  object
#  9   Idade Motorista        13002 non-null  int64
#  10  Viagens                13002 non-null  int64
#  11  ID Consumidor          13002 non-null  object
#  12  Nome Clinte            13002 non-null  object
#  13  Idade Cliente          13002 non-null  int64
# ...

# %%
df.describe()
# Out:
#        Valor Pedido  Total Itens Entregues  Volume Não Entregue  \
# count  13002.000000           13002.000000         13002.000000
# mean     297.380183               9.972927             0.382172
# std      202.540864               5.479447             0.559648
# min       20.080000               1.000000             0.000000
# 25%      149.895000               5.000000             0.000000
# 50%      277.380000              10.000000             0.000000
# 75%      403.457500              15.000000             1.000000
# max     1386.000000              19.000000             3.000000
#
#        Idade Motorista       Viagens  Idade Cliente        Preco
# count     13002.000000  13002.000000   13002.000000  1662.000000
# mean         34.936010     45.419397      54.266421    89.875217
# std          15.524684     19.431296      20.975537   201.186840
# min          18.000000     11.000000      18.000000     2.160000
# ...

# %%
df_filtro_1 = df[df['Volume Não Entregue'] != 0]

# %%
df_filtro_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4504 entries, 6 to 12998
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Data do Pedido         4504 non-null   object
#  1   ID Pedido              4504 non-null   object
#  2   Valor Pedido           4504 non-null   float64
#  3   Região                 4504 non-null   object
#  4   Total Itens Entregues  4504 non-null   int64
#  5   Volume Não Entregue    4504 non-null   int64
#  6   Hora da Entrega        4504 non-null   object
#  7   ID Entregador          4504 non-null   object
#  8   Nome Motorista         4504 non-null   object
#  9   Idade Motorista        4504 non-null   int64
#  10  Viagens                4504 non-null   int64
#  11  ID Consumidor          4504 non-null   object
#  12  Nome Clinte            4504 non-null   object
#  13  Idade Cliente          4504 non-null   int64
# ...

# %%
df_filtro_1 = df_filtro_1.dropna(subset=['product_id'])

# %%
df_filtro_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1662 entries, 6 to 12996
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Data do Pedido         1662 non-null   object
#  1   ID Pedido              1662 non-null   object
#  2   Valor Pedido           1662 non-null   float64
#  3   Região                 1662 non-null   object
#  4   Total Itens Entregues  1662 non-null   int64
#  5   Volume Não Entregue    1662 non-null   int64
#  6   Hora da Entrega        1662 non-null   object
#  7   ID Entregador          1662 non-null   object
#  8   Nome Motorista         1662 non-null   object
#  9   Idade Motorista        1662 non-null   int64
#  10  Viagens                1662 non-null   int64
#  11  ID Consumidor          1662 non-null   object
#  12  Nome Clinte            1662 non-null   object
#  13  Idade Cliente          1662 non-null   int64
# ...

# %%
df_filtro_1.to_excel('df_filtro_1.xlsx', index=False)
files.download('df_filtro_1.xlsx')

# %%
df_filtro_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1662 entries, 6 to 12996
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Data do Pedido         1662 non-null   object
#  1   ID Pedido              1662 non-null   object
#  2   Valor Pedido           1662 non-null   float64
#  3   Região                 1662 non-null   object
#  4   Total Itens Entregues  1662 non-null   int64
#  5   Volume Não Entregue    1662 non-null   int64
#  6   Hora da Entrega        1662 non-null   object
#  7   ID Entregador          1662 non-null   object
#  8   Nome Motorista         1662 non-null   object
#  9   Idade Motorista        1662 non-null   int64
#  10  Viagens                1662 non-null   int64
#  11  ID Consumidor          1662 non-null   object
#  12  Nome Clinte            1662 non-null   object
#  13  Idade Cliente          1662 non-null   int64
# ...
